# %%
september = 30
rain = 12
wind = 8
cold = 4
rain_wind = 5
rain_cold = 3
wind_cold = 2
rain_wind_cold = 1

good_weather = september - rain - wind - cold + rain_wind + rain_cold + wind_cold - rain_wind_cold

print(f'У вересні було {good_weather} днів гарної погоди')
# Out:
# У вересні було 15 днів гарної погоди

# %%
import matplotlib.pyplot as plt
from matplotlib_venn import venn3

venn3(subsets = (12, 8, 5, 4, 3, 2, 1), set_labels = ('Дощ', 'Вітер', 'Холод'))
plt.show()
