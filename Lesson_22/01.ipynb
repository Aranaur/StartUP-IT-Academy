# %%
math = 15
physics = 16
chemistry = 19
math_phy = 7
math_chem = 9
phy_chem = 6
math_phy_chem = 4

min_one = math + physics + chemistry - math_phy - math_chem - phy_chem + math_phy_chem

print(f'Хоча б по одній відмінній оцінці отримали {min_one} студентів')
# Out:
# Хоча б по одній відмінній оцінці отримали 32 студентів

# %%
import matplotlib.pyplot as plt
from matplotlib_venn import venn3

venn3(subsets = (15, 16, 7, 19, 9, 6, 4), set_labels = ('Математика', 'Фізика', 'Хімія'))
plt.show()
