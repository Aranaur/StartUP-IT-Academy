# %%
import random
from random_words import RandomWords
import time

int_list = [random.randint(0, 1000) for _ in range(5000)]

float_list = [random.uniform(0.1, 100) for _ in range(5000)]

w = RandomWords()
str_list = w.random_words(count=5000)


def bubble_sort(data):
    length = len(data)
    for iIndex in range(length):
        swapped = False
        for jIndex in range(0, length - iIndex - 1):
            if data[jIndex] > data[jIndex + 1]:
                data[jIndex], data[jIndex + 1] = data[jIndex + 1], data[jIndex]
                swapped = True
        if not swapped:
            break
    # print("Bubble Sort: ", data)


def partition(nums, low, high):
    pivot = nums[(low + high) // 2]
    i = low - 1
    j = high + 1
    while True:
        i += 1
        while nums[i] < pivot:
            i += 1

        j -= 1
        while nums[j] > pivot:
            j -= 1

        if i >= j:
            return j

        nums[i], nums[j] = nums[j], nums[i]


def quick_sort(nums):
    def _quick_sort(items, low, high):
        if low < high:
            split_index = partition(items, low, high)
            _quick_sort(items, low, split_index)
            _quick_sort(items, split_index + 1, high)
    _quick_sort(nums, 0, len(nums) - 1)


def time_reps_bubble(list_to_sort, reps):
    time_list = []
    for i in range(reps):
        start = time.time()
        bubble_sort(list_to_sort)
        time_list.append(time.time() - start)
    print(f'Mean time to run {type(list_to_sort[0])} = {sum(time_list) / reps}')


def time_reps_quick(list_to_sort, reps):
    time_list = []
    for i in range(reps):
        start = time.time()
        quick_sort(list_to_sort)
        time_list.append(time.time() - start)
    print(f'Mean time to run {type(list_to_sort[0])} = {sum(time_list) / reps}')

# %%
# %%timeit

print('\nBubble time', '*'*30)
time_reps_bubble(int_list, 100)
time_reps_bubble(float_list, 100)
time_reps_bubble(str_list, 100)
# Out:
# Bubble time ******************************
# Mean time to run <class 'int'> = 0.00037409305572509764
# Mean time to run <class 'float'> = 0.0003789973258972168
# Mean time to run <class 'str'> = 0.0004094719886779785
#
# Bubble time ******************************
# Mean time to run <class 'int'> = 0.00033486127853393554
# Mean time to run <class 'float'> = 0.00036905527114868166
# Mean time to run <class 'str'> = 0.0004040956497192383
#
# Bubble time ******************************
# Mean time to run <class 'int'> = 0.00041887521743774416
# Mean time to run <class 'float'> = 0.0005186605453491211
# Mean time to run <class 'str'> = 0.0004438567161560059
#
# Bubble time ******************************
# Mean time to run <class 'int'> = 0.00034938812255859376
# Mean time to run <class 'float'> = 0.000355074405670166
# Mean time to run <class 'str'> = 0.00040869951248168946
#
# Bubble time ******************************
# Mean time to run <class 'int'> = 0.00033980369567871094
# Mean time to run <class 'float'> = 0.0003743767738342285
# Mean time to run <class 'str'> = 0.00041887521743774416
#
# Bubble time ******************************
# Mean time to run <class 'int'> = 0.0003553009033203125
# Mean time to run <class 'float'> = 0.00041858673095703127
# Mean time to run <class 'str'> = 0.00041887521743774416
#
# Bubble time ******************************
# Mean time to run <class 'int'> = 0.0003349590301513672
# Mean time to run <class 'float'> = 0.00038931608200073244
# Mean time to run <class 'str'> = 0.00040920495986938475
#
# Bubble time ******************************
# Mean time to run <class 'int'> = 0.00034450531005859376
# Mean time to run <class 'float'> = 0.00040918350219726563
# Mean time to run <class 'str'> = 0.0004040646553039551
#
# Bubble time ******************************
# Mean time to run <class 'int'> = 0.00034940719604492187
# Mean time to run <class 'float'> = 0.001535801887512207
# Mean time to run <class 'str'> = 0.0004986977577209473
#
# Bubble time ******************************
# Mean time to run <class 'int'> = 0.0003291034698486328
# Mean time to run <class 'float'> = 0.0004246020317077637
# Mean time to run <class 'str'> = 0.0003989815711975098
#
# Bubble time ******************************
# Mean time to run <class 'int'> = 0.00036487579345703127
# Mean time to run <class 'float'> = 0.0003689789772033691
# Mean time to run <class 'str'> = 0.0004085874557495117
#
# Bubble time ******************************
# Mean time to run <class 'int'> = 0.0003142833709716797
# Mean time to run <class 'float'> = 0.0003291177749633789
# Mean time to run <class 'str'> = 0.0004188990592956543
#
# Bubble time ******************************
# Mean time to run <class 'int'> = 0.00032423973083496095
# Mean time to run <class 'float'> = 0.0003390955924987793
# Mean time to run <class 'str'> = 0.00041890621185302734
#
# Bubble time ******************************
# Mean time to run <class 'int'> = 0.000324254035949707
# Mean time to run <class 'float'> = 0.00032909631729125975
# Mean time to run <class 'str'> = 0.00039517641067504883
#
# Bubble time ******************************
# Mean time to run <class 'int'> = 0.00032875537872314455
# Mean time to run <class 'float'> = 0.001072375774383545
# Mean time to run <class 'str'> = 0.00044881582260131837
#
# Bubble time ******************************
# Mean time to run <class 'int'> = 0.00036414861679077146
# Mean time to run <class 'float'> = 0.00033910512924194335
# Mean time to run <class 'str'> = 0.00040914297103881834
#
# Bubble time ******************************
# Mean time to run <class 'int'> = 0.0003346467018127441
# Mean time to run <class 'float'> = 0.0003488612174987793
# Mean time to run <class 'str'> = 0.0003940844535827637
#
# Bubble time ******************************
# Mean time to run <class 'int'> = 0.0003390932083129883
# Mean time to run <class 'float'> = 0.0004391813278198242
# Mean time to run <class 'str'> = 0.00040485620498657225
#
# Bubble time ******************************
# Mean time to run <class 'int'> = 0.00043912649154663084
# Mean time to run <class 'float'> = 0.0003246474266052246
# Mean time to run <class 'str'> = 0.00039895057678222655
#
# Bubble time ******************************
# Mean time to run <class 'int'> = 0.00033945798873901366
# Mean time to run <class 'float'> = 0.0003441929817199707
# Mean time to run <class 'str'> = 0.0004089546203613281
#
# Bubble time ******************************
# Mean time to run <class 'int'> = 0.00031914949417114255
# Mean time to run <class 'float'> = 0.0003452086448669434
# Mean time to run <class 'str'> = 0.00039888858795166014
#
# Bubble time ******************************
# Mean time to run <class 'int'> = 0.0003295469284057617
# Mean time to run <class 'float'> = 0.0003338479995727539
# Mean time to run <class 'str'> = 0.0004188966751098633
#
# Bubble time ******************************
# Mean time to run <class 'int'> = 0.00031982421875
# Mean time to run <class 'float'> = 0.0003748321533203125
# Mean time to run <class 'str'> = 0.0004088306427001953
#
# Bubble time ******************************
# Mean time to run <class 'int'> = 0.0003253173828125
# Mean time to run <class 'float'> = 0.00033878564834594727
# Mean time to run <class 'str'> = 0.00040889501571655273
#
# Bubble time ******************************
# Mean time to run <class 'int'> = 0.00033488035202026365
# Mean time to run <class 'float'> = 0.00046907424926757814
# Mean time to run <class 'str'> = 0.0003887510299682617
#
# Bubble time ******************************
# Mean time to run <class 'int'> = 0.00031947851181030274
# Mean time to run <class 'float'> = 0.00034876108169555663
# Mean time to run <class 'str'> = 0.00038504838943481445
#
# Bubble time ******************************
# Mean time to run <class 'int'> = 0.00031882286071777344
# Mean time to run <class 'float'> = 0.0003393054008483887
# Mean time to run <class 'str'> = 0.00046390771865844726
#
# Bubble time ******************************
# Mean time to run <class 'int'> = 0.0003291058540344238
# Mean time to run <class 'float'> = 0.00042887210845947264
# Mean time to run <class 'str'> = 0.0003947782516479492
#
# Bubble time ******************************
# Mean time to run <class 'int'> = 0.0003487133979797363
# Mean time to run <class 'float'> = 0.00034447669982910154
# Mean time to run <class 'str'> = 0.0003989410400390625
#
# Bubble time ******************************
# Mean time to run <class 'int'> = 0.000329127311706543
# Mean time to run <class 'float'> = 0.00034532785415649416
# Mean time to run <class 'str'> = 0.0004989767074584961
#
# Bubble time ******************************
# Mean time to run <class 'int'> = 0.00031886577606201174
# Mean time to run <class 'float'> = 0.0003350949287414551
# Mean time to run <class 'str'> = 0.0004285001754760742
#
# Bubble time ******************************
# Mean time to run <class 'int'> = 0.00030950069427490237
# Mean time to run <class 'float'> = 0.0003446149826049805
# Mean time to run <class 'str'> = 0.00040892124176025393
#
# Bubble time ******************************
# Mean time to run <class 'int'> = 0.0003150057792663574
# Mean time to run <class 'float'> = 0.00039894819259643553
# Mean time to run <class 'str'> = 0.00039928197860717774
#
# Bubble time ******************************
# Mean time to run <class 'int'> = 0.0003247547149658203
# Mean time to run <class 'float'> = 0.00037867307662963867
# Mean time to run <class 'str'> = 0.0004196381568908691
#
# Bubble time ******************************
# Mean time to run <class 'int'> = 0.00033458948135375974
# Mean time to run <class 'float'> = 0.0003492927551269531
# Mean time to run <class 'str'> = 0.0003850960731506348
#
# Bubble time ******************************
# Mean time to run <class 'int'> = 0.0003789854049682617
# Mean time to run <class 'float'> = 0.00033908605575561524
# Mean time to run <class 'str'> = 0.00043496370315551755
#
# Bubble time ******************************
# Mean time to run <class 'int'> = 0.0003287672996520996
# Mean time to run <class 'float'> = 0.0003391361236572266
# Mean time to run <class 'str'> = 0.00039406538009643553
#
# Bubble time ******************************
# Mean time to run <class 'int'> = 0.0003291106224060059
# Mean time to run <class 'float'> = 0.0003494358062744141
# Mean time to run <class 'str'> = 0.00040471553802490234
#
# Bubble time ******************************
# Mean time to run <class 'int'> = 0.0004388260841369629
# Mean time to run <class 'float'> = 0.0003937506675720215
# Mean time to run <class 'str'> = 0.0004391837120056152
#
# Bubble time ******************************
# Mean time to run <class 'int'> = 0.0003693485260009766
# Mean time to run <class 'float'> = 0.00033490419387817384
# Mean time to run <class 'str'> = 0.00040891647338867185
#
# Bubble time ******************************
# Mean time to run <class 'int'> = 0.00032428741455078127
# Mean time to run <class 'float'> = 0.0003390812873840332
# Mean time to run <class 'str'> = 0.00039893627166748047
#
# Bubble time ******************************
# Mean time to run <class 'int'> = 0.00033425092697143556
# Mean time to run <class 'float'> = 0.00037900209426879885
# Mean time to run <class 'str'> = 0.0004095625877380371
#
# Bubble time ******************************
# Mean time to run <class 'int'> = 0.00036492109298706053
# Mean time to run <class 'float'> = 0.00033910751342773436
# Mean time to run <class 'str'> = 0.00039474964141845704
#
# Bubble time ******************************
# Mean time to run <class 'int'> = 0.00032913923263549804
# Mean time to run <class 'float'> = 0.000359039306640625
# Mean time to run <class 'str'> = 0.0004742574691772461
#
# Bubble time ******************************
# Mean time to run <class 'int'> = 0.0005984258651733398
# Mean time to run <class 'float'> = 0.00034519195556640623
# Mean time to run <class 'str'> = 0.0004288864135742188
#
# Bubble time ******************************
# Mean time to run <class 'int'> = 0.00031913280487060546
# Mean time to run <class 'float'> = 0.00034421682357788086
# Mean time to run <class 'str'> = 0.0007081556320190429
#
# Bubble time ******************************
# Mean time to run <class 'int'> = 0.00034448146820068357
# Mean time to run <class 'float'> = 0.0004886984825134277
# Mean time to run <class 'str'> = 0.0004638957977294922
#
# Bubble time ******************************
# Mean time to run <class 'int'> = 0.0005587387084960937
# Mean time to run <class 'float'> = 0.0003741288185119629
# Mean time to run <class 'str'> = 0.0004485797882080078
#
# Bubble time ******************************
# Mean time to run <class 'int'> = 0.00041888952255249025
# Mean time to run <class 'float'> = 0.0004239964485168457
# Mean time to run <class 'str'> = 0.0004188799858093262
#
# Bubble time ******************************
# Mean time to run <class 'int'> = 0.0004439616203308105
# Mean time to run <class 'float'> = 0.0005086660385131836
# Mean time to run <class 'str'> = 0.0004050183296203613
#
# Bubble time ******************************
# Mean time to run <class 'int'> = 0.00032874584197998044
# Mean time to run <class 'float'> = 0.0003690385818481445
# Mean time to run <class 'str'> = 0.0003847336769104004
#
# Bubble time ******************************
# Mean time to run <class 'int'> = 0.000489046573638916
# Mean time to run <class 'float'> = 0.0003353285789489746
# Mean time to run <class 'str'> = 0.0003989386558532715
#
# Bubble time ******************************
# Mean time to run <class 'int'> = 0.0003387284278869629
# Mean time to run <class 'float'> = 0.00035418272018432616
# Mean time to run <class 'str'> = 0.0004188823699951172
#
# Bubble time ******************************
# Mean time to run <class 'int'> = 0.00042495965957641604
# Mean time to run <class 'float'> = 0.0003989458084106445
# Mean time to run <class 'str'> = 0.00045894861221313477
#
# Bubble time ******************************
# Mean time to run <class 'int'> = 0.00037456274032592773
# Mean time to run <class 'float'> = 0.0003690409660339355
# Mean time to run <class 'str'> = 0.00041404008865356443
#
# Bubble time ******************************
# Mean time to run <class 'int'> = 0.0003393650054931641
# Mean time to run <class 'float'> = 0.0005087041854858398
# Mean time to run <class 'str'> = 0.00048445701599121095
#
# Bubble time ******************************
# Mean time to run <class 'int'> = 0.00039858579635620116
# Mean time to run <class 'float'> = 0.00032459020614624025
# Mean time to run <class 'str'> = 0.00045845508575439455
#
# Bubble time ******************************
# Mean time to run <class 'int'> = 0.0003291130065917969
# Mean time to run <class 'float'> = 0.0003344845771789551
# Mean time to run <class 'str'> = 0.0004491138458251953
#
# Bubble time ******************************
# Mean time to run <class 'int'> = 0.00033922433853149413
# Mean time to run <class 'float'> = 0.00033473968505859375
# Mean time to run <class 'str'> = 0.0003986191749572754
#
# Bubble time ******************************
# Mean time to run <class 'int'> = 0.0003549718856811523
# Mean time to run <class 'float'> = 0.00043897390365600587
# Mean time to run <class 'str'> = 0.0003886532783508301
#
# Bubble time ******************************
# Mean time to run <class 'int'> = 0.000364534854888916
# Mean time to run <class 'float'> = 0.00033872127532958985
# Mean time to run <class 'str'> = 0.0005044388771057129
#
# Bubble time ******************************
# Mean time to run <class 'int'> = 0.00031913280487060546
# Mean time to run <class 'float'> = 0.00034906864166259763
# Mean time to run <class 'str'> = 0.00039411306381225585
#
# Bubble time ******************************
# Mean time to run <class 'int'> = 0.00032912015914916994
# Mean time to run <class 'float'> = 0.0003490662574768066
# Mean time to run <class 'str'> = 0.0004041528701782227
#
# Bubble time ******************************
# Mean time to run <class 'int'> = 0.0003291153907775879
# Mean time to run <class 'float'> = 0.00033947944641113284
# Mean time to run <class 'str'> = 0.0003943681716918945
#
# Bubble time ******************************
# Mean time to run <class 'int'> = 0.0004787230491638184
# Mean time to run <class 'float'> = 0.00036417007446289064
# Mean time to run <class 'str'> = 0.0004089069366455078
#
# Bubble time ******************************
# Mean time to run <class 'int'> = 0.00032915830612182615
# Mean time to run <class 'float'> = 0.00034419775009155275
# Mean time to run <class 'str'> = 0.0004092717170715332
#
# Bubble time ******************************
# Mean time to run <class 'int'> = 0.00032877206802368165
# Mean time to run <class 'float'> = 0.0004243326187133789
# Mean time to run <class 'str'> = 0.0004287028312683105
#
# Bubble time ******************************
# Mean time to run <class 'int'> = 0.0003340506553649902
# Mean time to run <class 'float'> = 0.0004886841773986817
# Mean time to run <class 'str'> = 0.000385589599609375
#
# Bubble time ******************************
# Mean time to run <class 'int'> = 0.0003291153907775879
# Mean time to run <class 'float'> = 0.00035904407501220704
# Mean time to run <class 'str'> = 0.0004150390625
#
# Bubble time ******************************
# Mean time to run <class 'int'> = 0.00033872127532958985
# Mean time to run <class 'float'> = 0.00033909082412719727
# Mean time to run <class 'str'> = 0.0005537557601928711
#
# Bubble time ******************************
# Mean time to run <class 'int'> = 0.0003793811798095703
# Mean time to run <class 'float'> = 0.00041503190994262695
# Mean time to run <class 'str'> = 0.0004587674140930176
#
# Bubble time ******************************
# Mean time to run <class 'int'> = 0.00032914400100708007
# Mean time to run <class 'float'> = 0.0003351569175720215
# Mean time to run <class 'str'> = 0.00039862871170043946
#
# Bubble time ******************************
# Mean time to run <class 'int'> = 0.0003195810317993164
# Mean time to run <class 'float'> = 0.00036442041397094727
# Mean time to run <class 'str'> = 0.0003889560699462891
#
# Bubble time ******************************
# Mean time to run <class 'int'> = 0.00032425880432128905
# Mean time to run <class 'float'> = 0.0003789973258972168
# Mean time to run <class 'str'> = 0.0004196000099182129
#
# Bubble time ******************************
# Mean time to run <class 'int'> = 0.0003248238563537598
# Mean time to run <class 'float'> = 0.0003392457962036133
# Mean time to run <class 'str'> = 0.00038861513137817383
#
# Bubble time ******************************
# Mean time to run <class 'int'> = 0.0003748917579650879
# Mean time to run <class 'float'> = 0.00034917593002319335
# Mean time to run <class 'str'> = 0.00048462629318237306
#
# Bubble time ******************************
# Mean time to run <class 'int'> = 0.0003391194343566894
# Mean time to run <class 'float'> = 0.0003490400314331055
# Mean time to run <class 'str'> = 0.0003951478004455566
#
# Bubble time ******************************
# Mean time to run <class 'int'> = 0.00033910274505615233
# Mean time to run <class 'float'> = 0.00034978866577148435
# Mean time to run <class 'str'> = 0.00039374113082885743
#
# Bubble time ******************************
# Mean time to run <class 'int'> = 0.0003194880485534668
# Mean time to run <class 'float'> = 0.00034945011138916017
# Mean time to run <class 'str'> = 0.0004147195816040039
#
# Bubble time ******************************
# Mean time to run <class 'int'> = 0.0004088711738586426
# Mean time to run <class 'float'> = 0.0003448152542114258
# Mean time to run <class 'str'> = 0.00045871496200561524
#
# Bubble time ******************************
# Mean time to run <class 'int'> = 0.0003288817405700684
# Mean time to run <class 'float'> = 0.0003945732116699219
# Mean time to run <class 'str'> = 0.0005089402198791504
# 116 ms ± 4.64 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %%timeit

print('\nQuick time', '*'*30)
time_reps_quick(int_list, 100)
time_reps_quick(float_list, 100)
time_reps_quick(str_list, 100)
# Out:
# Quick time ******************************
# Mean time to run <class 'int'> = 0.006799485683441162
# Mean time to run <class 'float'> = 0.005565378665924072
# Mean time to run <class 'str'> = 0.006015882492065429
#
# Quick time ******************************
# Mean time to run <class 'int'> = 0.006275761127471924
# Mean time to run <class 'float'> = 0.005510098934173584
# Mean time to run <class 'str'> = 0.006257181167602539
#
# Quick time ******************************
# Mean time to run <class 'int'> = 0.006216731071472168
# Mean time to run <class 'float'> = 0.005314757823944092
# Mean time to run <class 'str'> = 0.00602816104888916
#
# Quick time ******************************
# Mean time to run <class 'int'> = 0.006610493659973144
# Mean time to run <class 'float'> = 0.005767514705657959
# Mean time to run <class 'str'> = 0.005850160121917724
#
# Quick time ******************************
# Mean time to run <class 'int'> = 0.006071245670318604
# Mean time to run <class 'float'> = 0.0055449938774108885
# Mean time to run <class 'str'> = 0.006407010555267334
#
# Quick time ******************************
# Mean time to run <class 'int'> = 0.006531088352203369
# Mean time to run <class 'float'> = 0.00546299695968628
# Mean time to run <class 'str'> = 0.006330561637878418
#
# Quick time ******************************
# Mean time to run <class 'int'> = 0.006006071567535401
# Mean time to run <class 'float'> = 0.005572061538696289
# Mean time to run <class 'str'> = 0.006005885601043701
#
# Quick time ******************************
# Mean time to run <class 'int'> = 0.006167666912078857
# Mean time to run <class 'float'> = 0.00547863245010376
# Mean time to run <class 'str'> = 0.006027457714080811
# 1.79 s ± 28.6 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
